# %% [markdown]
# 1. Crea un programa que imprima los números desde -30 hasta 50.
#
# Para cada número, además de imprimirlo, el programa debe mostrar un texto según estas reglas:
#
# si el número es menor que 0, mostrar "Muy frío"
# si el número está entre 0 y 24, mostrar "Templado"
# si el número es mayor o igual a 25, mostrar "Caluroso"

# %%
# lista desde -30 al 50
lista_numeros = range(-30,50)
print (lista_numeros)

for x in range(-30,51):
  if (x < 0):
    print(x, "Muy frío")
  elif(x >= 0 and x <= 24):
    print(x, "Templado")
  else:
      print(x, "Caluroso")
# Out:
# range(-30, 50)
# -30 Muy frío
# -29 Muy frío
# -28 Muy frío
# -27 Muy frío
# -26 Muy frío
# -25 Muy frío
# -24 Muy frío
# -23 Muy frío
# -22 Muy frío
# -21 Muy frío
# -20 Muy frío
# -19 Muy frío
# -18 Muy frío
# -17 Muy frío
# -16 Muy frío
# -15 Muy frío
# -14 Muy frío
# -13 Muy frío
# -12 Muy frío
# -11 Muy frío
# -10 Muy frío
# -9 Muy frío
# -8 Muy frío
# -7 Muy frío
# -6 Muy frío
# -5 Muy frío
# -4 Muy frío
# -3 Muy frío
# -2 Muy frío
# -1 Muy frío
# 0 Templado
# 1 Templado
# 2 Templado
# 3 Templado
# 4 Templado
# 5 Templado
# 6 Templado
# 7 Templado
# 8 Templado
# 9 Templado
# 10 Templado
# 11 Templado
# 12 Templado
# 13 Templado
# 14 Templado
# 15 Templado
# 16 Templado
# 17 Templado
# 18 Templado
# 19 Templado
# 20 Templado
# 21 Templado
# 22 Templado
# 23 Templado
# 24 Templado
# 25 Caluroso
# 26 Caluroso
# 27 Caluroso
# 28 Caluroso
# 29 Caluroso
# 30 Caluroso
# 31 Caluroso
# 32 Caluroso
# 33 Caluroso
# 34 Caluroso
# 35 Caluroso
# 36 Caluroso
# 37 Caluroso
# 38 Caluroso
# 39 Caluroso
# 40 Caluroso
# 41 Caluroso
# 42 Caluroso
# 43 Caluroso
# 44 Caluroso
# 45 Caluroso
# 46 Caluroso
# 47 Caluroso
# 48 Caluroso
# 49 Caluroso
# 50 Caluroso

# %% [markdown]
# 2. Crea un programa que imprima los números del 1 al 100 que sean divisibles por 5.
#
# Además, el programa debe cumplir estas condiciones:
#
# si el número es divisible por 5, imprimir el número junto con el texto "Bip" si el número también es divisible por 10, imprimir el número junto con el texto "Bip Bip" Ejemplo de salida

# %%
lista_numeros = range (1,101)

for x in range (1,101):
    if x % 10 == 0:
       print (x, "bip bip")
    elif x % 5 == 0:
        print (x, "bip")
# Out:
# 5 bip
# 10 bip bip
# 15 bip
# 20 bip bip
# 25 bip
# 30 bip bip
# 35 bip
# 40 bip bip
# 45 bip
# 50 bip bip
# 55 bip
# 60 bip bip
# 65 bip
# 70 bip bip
# 75 bip
# 80 bip bip
# 85 bip
# 90 bip bip
# 95 bip
# 100 bip bip

# %% [markdown]
# Problema 3. Detector de puntaje gamer
# Crea un programa que solicite al usuario dos números, los sume y luego muestre un mensaje según el resultado.
#
# Reglas
#
# si la suma es menor que 50, mostrar "Nivel principiante"
# si la suma es mayor o igual a 50 y menor que 80, mostrar "Nivel intermedio"
# si la suma es mayor o igual a 80, mostrar "Nivel pro"

# %%
# solicitud de números

num1 = int(input("primer número: "))
num2 = int(input("segundo número: "))

print("el resultado de tu suma es", num1+num2)

if suma < 50:
   print ("nivel principiante")
elif 50 <= suma < 80:
    print ("nivel intermedio")
else:
    print ("nivel pro")
# Out:
# primer número: 11
# segundo número: 11
# el resultado de tu suma es 22
# nivel pro

# %% [markdown]
# Problema 4. Calculador de perfil musical
# Crea un programa que evalúe el perfil del usuario según su edad y sus gustos.
#
# El usuario debe recibir los siguientes parámetros:
#
# edad
# le_gusta_musica
# le_gusta_bailar
# Y debe retornar uno de los siguientes mensajes:
#
# "Eres una estrella de la fiesta" si la persona tiene 18 o más años, le gusta la música y le gusta bailar
# "Te gusta la música, pero no tanto bailar" si le gusta la música pero no le gusta bailar
# "Tienes tu propio estilo" en cualquier otro caso

# %%
# perfil musical por edad

edad = int(input("tu edad: "))
le_gusta_bailar = (input("¿te gusta bailar? (si/no): ")).lower()
le_gusta_la_musica = (input("¿te gusta la música? (si/no): ")).lower()


le_gusta_bailar = le_gusta_bailar == "si"
le_gusta_la_musica = le_gusta_la_musica == "si"


if edad >= 18 and le_gusta_la_musica and le_gusta_bailar:
   print ("eres una estrella de la fiesta")
elif le_gusta_la_musica and not le_gusta_bailar:
   print ("te gusta la musica, pero no tanto bailar")
else:
   print ("tienes tu propio estilo")
